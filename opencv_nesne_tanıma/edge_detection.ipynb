# %%
import cv2 
import numpy as np 
from matplotlib import pyplot as plt

# %%
img = cv2.imread("DATA\\dog_face.jpg")

# %%
plt.imshow(img)

# %%
edge = cv2.Canny(img.copy() ,0,127)

# %%
plt.imshow(edge)

# %%
img = cv2.blur(img, (3,3))

# %%
edges = cv2.Canny(img , 100, 180 )

# %%
plt.imshow(edges)
