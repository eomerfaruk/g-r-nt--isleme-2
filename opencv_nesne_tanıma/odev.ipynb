# %%
import numpy as np 
import cv2 
from matplotlib import pyplot as plt

# %%
img = cv2.imread("DATA\\car_plate.jpg")

# %%
plt.imshow(img)

# %%
plate_cascade = cv2.CascadeClassifier("DATA\\haarcascades\\haarcascade_russian_plate_number.xml")

# %%
img = cv2.cvtColor(img , cv2.COLOR_BGR2RGB)

# %%
plate_rect = plate_cascade.detectMultiScale(img)

# %%
plate_rect
# Out:
# array([[419, 226,  75,  25],
#        [382, 217, 127,  42]])

# %%
for (x,y,w,h) in plate_rect:
    cv2.rectangle(img , (x,y),(x+w,y+h),(0,0,255),2)

# %%
plt.imshow(img)

# %%
[419, 226,  75,  25]

# %%
roi = img[226:250,419:490]

# %%
plt.imshow(roi)

# %%
blur = cv2.blur(img[226:250,419:490] , (5,5))

# %%
plt.imshow(blur)

# %%
img[226:250,419:490] = blur

# %%
plt.imshow(img)
