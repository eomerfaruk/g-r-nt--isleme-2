# %%
import cv2
import numpy as np
from matplotlib import pyplot  as plt

# %%
img = cv2.imread("DATA\\rainbow.jpg",0)

# %%
plt.imshow(img , cmap = "gray")

# %%
thresh = cv2.threshold(img, 127,255 ,cv2.THRESH_BINARY)[1]

# %%
plt.imshow(thresh,cmap = "gray")

# %%
thresh = cv2.threshold(img, 127,255 ,cv2.THRESH_BINARY_INV)[1]

# %%
plt.imshow(thresh , cmap = "gray")

# %%
img = cv2.imread("DATA\\crossword.jpg",0)
plt.imshow(img , cmap="gray")

# %%
thresh = cv2.threshold(img ,127,255,cv2.THRESH_BINARY)[1]

# %%
plt.imshow(thresh,cmap = "gray")

# %%
img = cv2.imread("DATA\\sudoku.jpg",0)

# %%
plt.imshow(img , cmap = "gray")

# %%
thresh_1 = cv2.threshold(img , 127,255 , cv2.THRESH_BINARY)[1]

# %%
plt.imshow(thresh_1 , cmap="gray") # görüntüdeki karatıların olmasının nedeni  görüntüdeki ışığın görüntünün her nokatsında aynı olmamasıdır

# %%
img.shape
# Out:
# (480, 640)

# %%
thresh_adaptive = cv2.adaptiveThreshold(img , 255 , cv2.ADAPTIVE_THRESH_MEAN_C ,cv2.THRESH_BINARY , 11 , 8 )

# %%
thresh_adaptive.shape
# Out:
# (480, 640)

# %%
plt.imshow(thresh_adaptive , cmap = "gray")

# %%
thresh_adaptive_gaus = cv2.adaptiveThreshold(img , 255 , cv2.ADAPTIVE_THRESH_GAUSSIAN_C ,cv2.THRESH_BINARY , 11 , 8 )

# %%
plt.imshow(thresh_adaptive_gaus , cmap="gray")
