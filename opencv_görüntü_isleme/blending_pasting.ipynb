# %%
import cv2 
import numpy as np 
from matplotlib import pyplot as plt

# %%
img = cv2.imread("DATA\\kopek.jpg")
img2 = cv2.imread("DATA\\watermark_no_copy.png")

# %%
img_rgb = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img2_rgb = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img_rgb)

# %%
plt.imshow(img2_rgb)

# %%
img_rgb.shape
# Out:
# (720, 1280, 3)

# %%
img2_rgb.shape
# Out:
# (1280, 1277, 3)

# %%
img_rgb = cv2.resize(img_rgb,(1200,1200)) #görüntünün yükseklik ve genişlik değerleri değiştirildi
img2_rgb = cv2.resize(img2_rgb,(1200,1200))

# %%
img_rgb.shape
# Out:
# (1200, 1200, 3)

# %%
blended = cv2.addWeighted(src1 = img_rgb , alpha = 0.5 , src2 = img2_rgb ,beta=0.5 ,gamma = 0)

# %%
plt.imshow(blended)

# %%
img2_rgb = cv2.resize(img2_rgb ,  (600,600))

# %%
plt.imshow(img_rgb)

# %%
plt.imshow(img2_rgb)

# %%
img_rgb[0:600 , 0:600] = img2_rgb

# %%
plt.imshow(img_rgb)

# %%
roi = img_rgb[0:720 ,600:1200]

# %%
plt.imshow(roi)

# %%
imggray = cv2.cvtColor(img2_rgb , cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(imggray , cmap = "gray")

# %%
mask_gray = cv2.bitwise_not(imggray)

# %%
plt.imshow(mask_gray , cmap = "gray")

# %%
mask_gray.shape
# Out:
# (600, 600)

# %%
white_background = np.full((600,600,3),255 , dtype = np.uint8)

# %%
white_background
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
white_background.shape
# Out:
# (600, 600, 3)

# %%
bk = cv2.bitwise_or(white_background , white_background , mask=mask_gray)

# %%
plt.imshow(bk)

# %%
fg = cv2.bitwise_or(img2_rgb , img2_rgb , mask = mask_gray)

# %%
plt.imshow(fg)

# %%
roi.shape
# Out:
# (720, 600, 3)

# %%
fg.shape
# Out:
# (600, 600, 3)

# %%
roi = img_rgb[ 120 : 720 , 600 : 1200 ]

# %%
final_roi = cv2.bitwise_or(roi , fg)

# %%
plt.imshow(final_roi)
